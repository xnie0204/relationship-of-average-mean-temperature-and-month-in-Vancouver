# %% [markdown]
# ### 1.  problem
#    relationship of average mean temperature and month in Vancouver
#
#
#    Build a line chart of average mean temperature per month against the month in 2016
# ### 2.  information
#    information source is: daily_weather_2016.csv, temp and month cell in the csv
# ### 3.  interesting
#    change of Vancouver temperture
# ### 4.design choices
#    a. creat a list of monthes
#    b.fiter the same month's list
#    c.caculate each month's average mean temp and creat a list
#    d. creat picture

# %% [markdown]
# ### 5. Problem Solving
# ![image.png](attachment:image.png)
# ### 6. Challenging
#    creat a suitable list for mean temperture per month
#
#
#    too many helper functions and Lists
#
# ### 7. Future Work
#    can show everywhere and everyyear's mean teampture's line chart if the format is right
